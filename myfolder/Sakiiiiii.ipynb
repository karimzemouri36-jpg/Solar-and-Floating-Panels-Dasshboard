# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
import pandas as pd

data = pd.read_csv("Sakidata.csv")
print(data.head())
# Out:
#    Depth_m  Production_flow_m3s  Injected_water_m3s  Total_flow_m3s  \
# 0        0             0.000648                 0.0        0.000648
# 1        5             0.000648                 0.0        0.000648
# 2       10             0.000648                 0.0        0.000648
# 3       15             0.000648                 0.0        0.000648
# 4       20             0.000648                 0.0        0.000648
#
#    Velocity_m_s    Reynolds  Friction_factor  Pressure_gravity_Pa  \
# 0      0.082525  350.730338         0.182476                  0.0
# 1      0.082525  350.730338         0.182476              41692.5
# 2      0.082525  350.730338         0.182476              83385.0
# 3      0.082525  350.730338         0.182476             125077.5
# 4      0.082525  350.730338         0.182476             166770.0
#
#    Pressure_friction_Pa  Total_pressure_Pa
# 0             26.407931        100000.0000
# 1             52.815863        141718.9079
# ...
